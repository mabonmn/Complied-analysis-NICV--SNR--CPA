# %% [markdown]
# <a href="https://colab.research.google.com/github/mabonmn/Complied-analysis-NICV--SNR--CPA/blob/main/Plot_For_Paper_ACMWISEC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import math
import numpy as np

# %%
x=[i for i in range(340, 411)]

# %%
y = [4155, 498, -1 , 494, 4248,
           409, -1, 310, 4548, 324, 
           -1, 336, -1, 229, -1, 354, -1, 267, -1, 219, -1, 
           237, -1, 189,-1, 228,-1, 232, -1, 369, -1, 447,-1, 
           329, -1, 547,-1, 819, -1, 754, -1, 1051, -1, 689, -1, 1082,-1, 
           614, -1, 681, -1, 1188, -1, -1, -1, 3166, -1, 3323, -1, 2955, 
           -1, -1, -1, 2686, 2363,-1, 2377, 888, -1, 1321, -1]
y = np.log2(y)
# Out:
# <ipython-input-3-7798ac722633>:8: RuntimeWarning: invalid value encountered in log2
#   y = np.log2(y)

# %%
for i in range(71):
  if(math.isnan(y[i])):
      plt.scatter(x[i],13,marker='^',color='red',s=60)
  else:  
    plt.scatter(x[i], y[i],marker='*',color='Blue',s=60)
plt.yticks([7,8,9,10,11,12,13],['2^7', '2^8', '2^9', '2^10', '2^11','2^12','2^13'])
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.show()

# %%
math.isnan(y[1])
# Out:
# False
